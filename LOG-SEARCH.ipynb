# %%
import os

# %%
path_dir='C:/Users/a818517/Documents/bugs/in-active-alert/Acc3 flink logs/Acc3 flink logs'
log_file=path_dir+"/Vm3/flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm3.log"

# %%
with open(log_file,'r', encoding='UTF-8') as reader:
        for line in reader:
            if 'CDC payload received' in line:
                print(line)

# %%
file_paths=[]
for log_files in os.listdir(path_dir):
    if os.path.isdir(path_dir+"/"+log_files):
        for files in os.listdir(path_dir+"/"+log_files):
            file_paths.append(path_dir+"/"+log_files+"/"+files)

# %%
for f in file_paths:
    with open(f,'r', encoding='UTF-8') as reader:
        for line in reader:
            if 'cdc' in line:
                print(line)

# %%
log_dir="C:/Users/a818517/Downloads/flink nw2 vm1 logs/Flinkh VM2 NW1 logs"

# %%
msg_len =len('Message transfer to raw bkp topic')
files = [ log_dir+"/"+f for f in os.listdir(log_dir)]
for f in files:
    with open(f,'r', encoding='UTF-8') as reader:
        for line in reader:
            if 'Message transfer to raw bkp topic' in line:
                line = line[line.index('Message transfer to raw bkp topic')+msg_len:]
                csv_line = ",".join(line.split("#"))
                with open("C:/Users/a818517/Downloads/flink nw2 vm1 logs/out/msg_mapping.csv",'a', encoding='UTF-8') as writer:
                    writer.write(csv_line)

# %%
vins = ['XLRACH4300G343343',
'XLRACM4100G160205',
'XLRACM4100G273518',
'XLRACM4100G274101',
'XLRACM4100G320151',
'XLRACM4100G335185',
'XLRACM4100G377226',
'XLRACM4300G298096',
'XLRACM4300G338684',
'XLRACM4300G345302',
'XLRADM4100G271265',
'XLRADM4100G307135',
'XLRADM4100G312304',
'XLRADM4100G331835',
'XLRADM4100G333290',
'XLRADM4100G333628',
'XLRADM4100G334000',
'XLRADM4100G344343',
'XLRADM4100G352819',
'XLRADM4100G354739',
'XLRADM4300G331742',
'XLRADM4300G332584',
'XLRAEH4100G341184',
'XLRAEH4300G344207',
'XLRAEH4300G354837',
'XLRAEL1500L461989',
'XLRAEL1500L487674',
'XLRAEL1500L489219',
'XLRAEL1500L489456',
'XLRAEL1500L489921',
'XLRAEL1500L490328',
'XLRAEL1500L490725',
'XLRAEL1500L492941',
'XLRAEL1500L493587',
'XLRAEL1500L494873',
'XLRAEL1500L495837',
'XLRAEL1500L496935',
'XLRAEL1500L496961',
'XLRAEL1500L497849',
'XLRAEL1500L500026',
'XLRAEL1500L500094',
'XLRAEL1500L501832',
'XLRAEL1500L501977',
'XLRAEL1500L502881',
'XLRAEL1500L503352',
'XLRAEL1500L504476',
'XLRAEL1500L504772',
'XLRAEL1500L505278',
'XLRAEL1500L505337',
'XLRAEL1500L505480',
'XLRAEL1500L506114',
'XLRAEL1500L506507',
'XLRAEL1500L507189',
'XLRAEL1500L507258',
'XLRAEL1500L514651',
'XLRAEL1500L517777',
'XLRAEL1500L530199',
'XLRAEL1500L533321',
'XLRAEL1500L533759',
'XLRAEL1500L534533',
'XLRAEL1500L534956',
'XLRAEL1700L490801',
'XLRAEL1700L492695',
'XLRAEL1700L499738',
'XLRAEL1700L502361',
'XLRAEL1700L502663',
'XLRAEL1700L502669',
'XLRAEL1700L502707',
'XLRAEL1700L506949',
'XLRASM4100G313838',
'XLRASM4100G315254',
'XLRASM4100G315580',
'XLRASM4100G315610',
'XLRASM4100G316083',
'XLRASM4100G318229',
'XLRASM4100G321895',
'XLRASM4100G326401',
'XLRASM4100G326442',
'XLRASM4100G333384',
'XLRASM4100G333713',
'XLRASM4100G347242',
'XLRASM4100G371169',
'XLRASM4100G383169',
'XLRASM4300G332394',
'XLRASM4300G336495',
'XLRASM4300G340501',
'XLRASM4300G376268',
'XLRASM4700G242820',
'XLRASM4700G317590',
'XLRATF5300G482824',
'XLRATH4300G342834',
'XLRATM4100G330845',
'XLRATM4100G340723',
'XLRATM4100G431545',
'XLRATM4100G431658',
'XLRATM4300G324037',
'XLRATM4300G329294',
'XLRATM4300G362899',
'XLRAWF5300G485099',
'XLRTEF5100G381581',
'XLRTEF5100G435508',
'XLRTEF5100G436621',
'XLRTEF5300G382251',
'XLRTEF5300G403540',
'XLRTEF5300G411660',
'XLRTEF5300G430645',
'XLRTEF5300G431053',
'XLRTEF5300G453820',
'XLRTEF5300G458527',
'XLRTEF5300G462129',
'XLRTEF5300G464718',
'XLRTEF5300G466651',
'XLRTEF5300G469451',
'XLRTEF5300G470080',
'XLRTEF5300G472477',
'XLRTEF5300G473261',
'XLRTEF5300G473262',
'XLRTEF5300G473263',
'XLRTEF5300G473274',
'XLRTEF5300G473687',
'XLRTEF5300G475296',
'XLRTEF5300G475550',
'XLRTEF5300G475633',
'XLRTEF5300G480210',
'XLRTEF5300G482828',
'XLRTEF5300G485055',
'XLRTEF5300G485077',
'XLRTEF5300G485152',
'XLRTEF5300G485161',
'XLRTEF5300G485162',
'XLRTEF5300G485168',
'XLRTEH4100G115626',
'XLRTEH4100G161563',
'XLRTEH4100G193075',
'XLRTEH4100G246836',
'XLRTEH4100G297249',
'XLRTEH4100G309275',
'XLRTEH4100G321553',
'XLRTEH4100G324246',
'XLRTEH4100G324744',
'XLRTEH4100G335928',
'XLRTEH4100G336584',
'XLRTEH4100G338693',
'XLRTEH4100G352683',
'XLRTEH4100G361583',
'XLRTEH4100G398539',
'XLRTEH4300G240941',
'XLRTEH4300G243117',
'XLRTEH4300G248775',
'XLRTEH4300G254318',
'XLRTEH4300G259400',
'XLRTEH4300G260205',
'XLRTEH4300G262382',
'XLRTEH4300G266027',
'XLRTEH4300G266529',
'XLRTEH4300G273960',
'XLRTEH4300G283275',
'XLRTEH4300G283380',
'XLRTEH4300G284025',
'XLRTEH4300G286265',
'XLRTEH4300G287888',
'XLRTEH4300G289168',
'XLRTEH4300G292494',
'XLRTEH4300G293496',
'XLRTEH4300G293556',
'XLRTEH4300G294987',
'XLRTEH4300G295158',
'XLRTEH4300G296891',
'XLRTEH4300G297064',
'XLRTEH4300G297489',
'XLRTEH4300G297625',
'XLRTEH4300G297700',
'XLRTEH4300G298256',
'XLRTEH4300G298332',
'XLRTEH4300G299200',
'XLRTEH4300G299319',
'XLRTEH4300G299360',
'XLRTEH4300G300012',
'XLRTEH4300G300217',
'XLRTEH4300G300233',
'XLRTEH4300G300533',
'XLRTEH4300G300543',
'XLRTEH4300G300790',
'XLRTEH4300G300913',
'XLRTEH4300G303326',
'XLRTEH4300G303683',
'XLRTEH4300G336654',
'XLRTEH4300G337284',
'XLRTEH4300G337702',
'XLRTEH4300G338057',
'XLRTEH4300G338158',
'XLRTEH4300G338160',
'XLRTEH4300G338261',
'XLRTEH4300G338304',
'XLRTEH4300G338398',
'XLRTEH4300G338643',
'XLRTEH4300G338731',
'XLRTEH4300G338732',
'XLRTEH4300G338868',
'XLRTEH4300G338945',
'XLRTEH4300G338977',
'XLRTEH4300G339067',
'XLRTEH4300G339191',
'XLRTEH4300G339435',
'XLRTEH4300G339440',
'XLRTEH4300G339685',
'XLRTEH4300G339728',
'XLRTEH4300G340472',
'XLRTEH4300G340770',
'XLRTEH4300G340780',
'XLRTEH4300G340826',
'XLRTEH4300G340830',
'XLRTEH4300G340851',
'XLRTEH4300G340859',
'XLRTEH4300G340877',
'XLRTEH4300G341023',
'XLRTEH4300G341073',
'XLRTEH4300G341085',
'XLRTEH4300G341107',
'XLRTEH4300G341170',
'XLRTEH4300G341196',
'XLRTEH4300G341252',
'XLRTEH4300G341284',
'XLRTEH4300G341779',
'XLRTEH4300G341875',
'XLRTEH4300G341882',
'XLRTEH4300G342021',
'XLRTEH4300G342187',
'XLRTEH4300G342384',
'XLRTEH4300G342482',
'XLRTEH4300G342523',
'XLRTEH4300G342632',
'XLRTEH4300G342639',
'XLRTEH4300G342735',
'XLRTEH4300G342806',
'XLRTEH4300G343056',
'XLRTEH4300G343141',
'XLRTEH4300G343190',
'XLRTEH4300G343220',
'XLRTEH4300G343409',
'XLRTEH4300G343521',
'XLRTEH4300G343814',
'XLRTEH4300G343908',
'XLRTEH4300G343927',
'XLRTEH4300G344437',
'XLRTEH4300G344493',
'XLRTEH4300G344763',
'XLRTEH4300G345321',
'XLRTEH4300G345784',
'XLRTEH4300G346284',
'XLRTEH4300G346308',
'XLRTEH4300G346865',
'XLRTEH4300G346874',
'XLRTEH4300G347294',
'XLRTEH4300G347467',
'XLRTEH4300G348372',
'XLRTEH4300G348865',
'XLRTEH4300G348872',
'XLRTEH4300G348981',
'XLRTEH4300G350456',
'XLRTEH4300G350837',
'XLRTEH4300G350867',
'XLRTEH4300G350996',
'XLRTEH4300G351041',
'XLRTEH4300G351558',
'XLRTEH4300G351601',
'XLRTEH4300G351642',
'XLRTEH4300G351745',
'XLRTEH4300G351817',
'XLRTEH4300G351940',
'XLRTEH4300G352113',
'XLRTEH4300G352205',
'XLRTEH4300G352289',
'XLRTEH4300G352331',
'XLRTEH4300G352518',
'XLRTEH4300G352520',
'XLRTEH4300G352535',
'XLRTEH4300G352580',
'XLRTEH4300G352839',
'XLRTEH4300G352905',
'XLRTEH4300G353201',
'XLRTEH4300G353230',
'XLRTEH4300G353543',
'XLRTEH4300G354290',
'XLRTEH4300G354383',
'XLRTEH4300G354437',
'XLRTEH4300G354654',
'XLRTEH4300G354878',
'XLRTEH4300G354990',
'XLRTEH4300G355086',
'XLRTEH4300G355304',
'XLRTEH4300G355643',
'XLRTEH4300G355649',
'XLRTEH4300G356253',
'XLRTEH4300G356380',
'XLRTEH4300G356385',
'XLRTEH4300G356443',
'XLRTEH4300G356534',
'XLRTEH4300G356696',
'XLRTEH4300G356732',
'XLRTEH4300G356843',
'XLRTGH4300G337225',
'XLRTGH4300G340970',
'XLRTGH4300G341344',
'XLRTGH4300G341920',
'XLRTGH4300G342984',
'XLRTGH4300G344533',
'XLRTGH4300G347287',
'XLRTGH4300G352971',
'XLRTGH4300G353704',
'XLRTGH4300G353837',
'XLRTGH4300G363011',
'XLRTGH4300G418426',
'XLRTGM4100G284843',
'XLRTGM4100G323675',
'XLRTGM4100G343660',
'XLRTGM4300G262313',
'XLRTGM4300G322128',
'XLRTGM4300G325131',
'XLRTGM4300G325820',
'XLRTGM4300G336766',
'XLRTGM4300G345773',
'XLRTSH4300G257090',
'XLRTSH4300G331499',
'XLRTSH4300G339706',
'XLRTTH4300G298317',
'XLRTTH4300G302597']

# %%
len(vins)
# Out:
# 671

# %%
csv_d = 'C:/Users/a818517/Downloads/flink nw2 vm1 logs/out/msg_mapping.csv'
with open(csv_d,'r',encoding='UTF-8') as reader:
    for line in reader:
        vin=line.split(",")[0]
        if vin.strip() in vins:
            with open('C:/Users/a818517/Downloads/flink nw2 vm1 logs/out/vins.csv','a',encoding='UTF-8') as writer:
                writer.write(line)

# %%
vins_no_mapping=['XLRAEL1500L533321',
'XLRAEL1500L533759',
'XLRAEL1500L534533',
'XLRAEL1500L534956',
'XLRAEL2700L532873',
'XLRAEL2700L533897',
'XLRAEL2700L533948',
'XLRAEL2700L534552',
'XLRAEL2700L534555',
'XLRAEL3700L533896',
'XLRAEL3700L533935',
'XLRASF5100G424113',
'XLRASF5300G457985',
'XLRASH4100G302999',
'XLRATF5300G482824',
'XLRATM4100G431545',
'XLRATM4100G431658',
'XLRAWF5300G485099',
'XLRTEF5100G381581',
'XLRTEF5100G436621',
'XLRTEF5300G382251',
'XLRTEF5300G431053',
'XLRTEF5300G458527',
'XLRTEF5300G462129',
'XLRTEF5300G464718',
'XLRTEF5300G466651',
'XLRTEF5300G469451',
'XLRTEF5300G470080',
'XLRTEF5300G472477',
'XLRTEF5300G473261',
'XLRTEF5300G473262',
'XLRTEF5300G473263',
'XLRTEF5300G473274',
'XLRTEF5300G475296',
'XLRTEF5300G475550',
'XLRTEF5300G475633',
'XLRTEF5300G480210',
'XLRTEF5300G482828',
'XLRTEF5300G485055',
'XLRTEF5300G485161',
'XLRTEF5300G485168',
'XLRTEH4300G350837',
'XLRTEH4300G364248',
'XLRTEH4300G369135',
'XLRTEH4300G482019',
'XLRTEH4300G485420',
'XLRTGF5300G462756',
'XLRTGF5300G479582',
'XLRTGF5300G480779',
'XLRTGF5300G482875',
'XLRTGF5300G483802',
'XLRTSH4300G257090'
]

# %%
len(vins_no_mapping)
# Out:
# 52

# %%
db_mapped_data='C:/Users/a818517/Desktop/missing-trip-analysis/db-mapped-data.csv'
data=[]
with open(db_mapped_data,'r',encoding='UTF-8') as reader:
    for line in reader:
        vin=line.split(",")[1]
        if vin.strip() in vins_no_mapping:
            data.append(line.strip())

len(data)
# Out:
# 2162

# %%
for line in data:
    with open('C:/Users/a818517/Desktop/missing-trip-analysis/false-db-mapping.csv','a+',encoding='UTF-8') as w:
        w.writelines(line+"\n")

# %%
# Out:
# 59

# %%
#GPT

# %%
lst_1 =list(range(1,1090))
len(lst_1)
# Out:
# 1089

# %%
"#####".join(map(str,lst_1))

# %%
# y = x2-x-2
import numpy as np

# %%
x = np.linspace(-10,11,150)
y = [ ((x1*x1) - x1 - 2) for x1 in x ]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
trip_id='1.0-0f145397-185f-45ad-8897-9c2816ddba22'
dir_file_path="C:/Users/a818517/Downloads/acc3 flink log (1)/vm4/flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.11"

# %%
print(dir_file_path)
# Out:
# C:/Users/a818517/Downloads/acc3 flink log (1)/vm4/flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.11

# %%
with open(dir_file_path,'r', encoding='UTF-8') as reader:
        for line in reader:
            if trip_id in line and 'Index alert process' in line:
                print(line)
# Out:
# 2023-10-17 07:56:53,973 INFO  net.atos.daf.ct2.util.Utils                                  [] {dt.trace_id=e7027c0cd12c513a3915855fd22d7072, dt.span_id=9f28313a1c96fcff, dt.trace_sampled=true} - Index alert process for  Index(vid=ddfd3b1c-97cc-4a2d-9206-47b1acc16fab, vin=XLRTEH4300G135560, vFuelStopPrevVal=88.4, evtId=4, averageSpeed=null, idleDuration=null, evtDateTime=2023-10-17T07:55:52.000Z, indexList=[{"receivedTimestamp":1697529518433,"EvtDateTime":"2023-10-17T07:55:52.000Z","TransID":"03000","VID":"ddfd3b1c-97cc-4a2d-9206-47b1acc16fab","VIN":"XLRTEH4300G135560","FuelType":"D","kafkaProcessingTS":"1697529425749","Jobname":"1.0-0f145397-185f-45ad-8897-9c2816ddba22","NumSeq":0,"VEvtID":4,"ROName":"CCU_3040007007","GPSLatitude":52.3497,"GPSLongitude":7.44908,"GPSAltitude":36,"GPSHeading":0.0,"DriverID":"9c1be44bacc8395e1486bc756dc086ce1a24708746fab04764625487af442752","DriverIDRenewalIndex":"03","VCumulatedFuel":133812332,"VDist":669624190,"VUsedFuel":0,"Document":{"TripID":"1.0-0
# ...

# %%
dir_file_path="C:/Users/a818517/Downloads/acc3 flink log (1)/vm4"
file_paths=[]
for log_files in os.listdir(dir_file_path):
    if os.path.isdir(dir_file_path+"/"+log_files):
        for files in os.listdir(path_dir+"/"+log_files):
            file_paths.append(dir_file_path+"/"+log_files+"/"+files)

# %%
os.listdir(dir_file_path)
# Out:
# ['flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.10',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.11',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.12',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.13',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.14',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.15',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.8',
#  'flink-flinkhuser-taskexecutor-0-dafct-lan5-d-euwe-cdp-flinkh2-vm4.log.9']
