# %%
import csv

# %%
unique_csv="C:/Users/a818517/Desktop/project-docs/hackthon-drive-time-alert/data/unique-NL-B0002991860000.csv"

# %%
dict_last={}
with open(unique_csv,'r',encoding='UTF-8') as reader:
    for line in reader:
        line=line.strip()
        data = line.split(",")
        state = data[3]
        time=data[9]
        if state=='2':
            print('current state 2')
            print('last_sate >> ',dict_last.get('last_sate'))
            pass
        else:
            dict_last={'last_sate':state,'time':time}
        print(dict_last)
# Out:
# {'last_sate': 'Driver1WorkingState', 'time': 'Time_In_Millies'}
# {'last_sate': '3', 'time': '1692933088.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933088.0'}
# {'last_sate': '3', 'time': '1692933298.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933298.0'}
# {'last_sate': '3', 'time': '1692933487.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933487.0'}
# {'last_sate': '3', 'time': '1692933558.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933558.0'}
# {'last_sate': '3', 'time': '1692933665.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933665.0'}
# {'last_sate': '3', 'time': '1692933701.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692933701.0'}
# {'last_sate': '3', 'time': '1692934777.0'}
# current state 2
# last_sate >>  3
# {'last_sate': '3', 'time': '1692934777.0'}
# {'last_sate': '3', 'time': '1692935588.0'}
# ...
