# %%
from matplotlib import pyplot as plt

# %%
x=[0,1,2]
b=2
y = [3*x1+b for x1 in x]
x_axix= [-3,-2,-1,0,1,2,3]
y_axix= [0,0,0,0,0,0,0]

x_y_axix= [0] * len(x_y_axix)
y_y_axix= list(range(0,9))
print(len(x_y_axix))
print(len(y_y_axix))
# Out:
# 9
# 9

# %%
plt.grid()
plt.plot(x,y,marker='o')
plt.plot(x_line,y_line,marker='o',color='black')
#plt.plot(x_y_axix,y_y_axix,marker='o',color='black')
plt.show()
